# %%
from IPython.core.display import HTML
HTML("""
<style>
.cm-s-ipython div.CodeMirror-selected {background: #0066ff !important;}
</style>
""")
# Out:
# <style>
# .cm-s-ipython div.CodeMirror-selected {background: #0066ff !important;}
# </style>

# %%
# %%html
# <style>
# .cm-s-ipython div.CodeMirror-selected {background: #0066ff !important;}
# </style>
# Out:
# <style>
# .cm-s-ipython div.CodeMirror-selected {background: #0066ff !important;}
# </style>

# %%
zfds

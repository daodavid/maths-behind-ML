# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import math
from mpl_toolkits.mplot3d import Axes3D
from random import random
#from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %% [markdown]
# <h1> notes </h1>

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1110)

# %%
count, bins, ignored = plt.hist(s, 30, density=True)
print(bins)
y =  1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2))
                      
plt.plot(bins, y, linewidth=2, color='r')
plt.show()
# Out:
# [-0.31460532 -0.2938554  -0.27310548 -0.25235556 -0.23160564 -0.21085572
#  -0.1901058  -0.16935588 -0.14860596 -0.12785604 -0.10710612 -0.0863562
#  -0.06560628 -0.04485636 -0.02410644 -0.00335652  0.0173934   0.03814332
#   0.05889324  0.07964316  0.10039308  0.121143    0.14189292  0.16264284
#   0.18339276  0.20414268  0.2248926   0.24564252  0.26639244  0.28714236
#   0.30789227]

# %% [markdown]
# $p(x) = \frac{1}{\sqrt{2\pi\sigma^2}}e^{-\frac{(x-\mu)^2}{2\sigma^2}}$

# %%
x= np.linspace(-3,3,s.size)
plt.scatter(x,s,s=0.1, marker='x')

# %%
new_s = 2*x+5 +s*10

# %%
plt.scatter(x,new_s,s=0.1, marker='x')

# %%
count, bins, ignored = plt.hist(s, 30, density=True)
print(bins)
y =  1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2))
                      
plt.plot(bins, y, linewidth=2, color='r')
plt.show()
# Out:
# [-0.31460532 -0.2938554  -0.27310548 -0.25235556 -0.23160564 -0.21085572
#  -0.1901058  -0.16935588 -0.14860596 -0.12785604 -0.10710612 -0.0863562
#  -0.06560628 -0.04485636 -0.02410644 -0.00335652  0.0173934   0.03814332
#   0.05889324  0.07964316  0.10039308  0.121143    0.14189292  0.16264284
#   0.18339276  0.20414268  0.2248926   0.24564252  0.26639244  0.28714236
#   0.30789227]

# %%
count, bins, ignored = plt.hist(new_s, 60, density=True)
sigma = np.std(new_s)
np.var(new_s)**(1/2)
mu = np.mean(new_s)
y =  1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2))
                      
plt.plot(bins, y, linewidth=2, color='r')

# %%
y =  1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2))

# %% [markdown]
# https://brunaw.com/phd/bayes-regression/report.pdf?fbclid=IwAR3qVUBkwEbkfrSs5h9gCMwhPM2niGtL6VNE9dlJM48MlaMSL0VWLB4s68c <br>
# https://www.le.ac.uk/users/dsgp1/COURSES/THIRDMET/MYLECTURES/1REGRESS.pdf <br>
# http://users.encs.concordia.ca/~doedel/courses/comp-233/slides.pdf

# %% [markdown]
# # Human activity statistic and data visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from mpl_toolkits import mplot3d

from sklearn.model_selection import train_test_split

from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA
import scikitplot as skplt
import datetime

# %%
train = pd.read_csv('https://disk.bg/s/UFQtiaqlTDj2SZX/download')  ### train data load
test = pd.read_csv('https://disk.bg/s/VYmtGL4lzcHdcCl/download')

# %% [markdown]
# The directors of the study created an incredible number of features from the two sensors.
#
# ### Dataset Exploration

# %%
train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X    ...     \
# ...

# %% [markdown]
# #### Splitting the data into train and validation

# %%
train_data_test = attribute_test.drop('Activity' , axis=1).values
label_data_test = attribute_test['Activity'].values


print('train data ' ,train_data.shape)
print('label data ' ,label_data.shape)

print('train data test ' ,train_data_test.shape)
print('label_data_test' ,label_data_test.shape)

# %% [markdown]
# ### Scaling the Data
#
# from sklearn.preprocessing import StandardScaler
# feature_scaler = StandardScaler()
# X_train = feature_scaler.fit_transform(X_train)
# X_test = feature_scaler.transform(X_test)

# %% [markdown]
# # Feature Selection (PCA)
#
# ### Predictive Modelling (SVM)
# ### Tuning HyperParameter (SVM)

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Title

# %% [markdown]
#  $$h_{\theta}(\vec{x})= \frac{1}{1+e^{-\vec{\theta}.\vec{X}}}=\frac{1}{1+e^{-\theta^T.X}}$$
#  $h_{\theta}(X)$ is also called sigmoid function ,graphicaly look like this :

# %%
A = np.empty_like
newrow = [2,4]

# %%
#utility


def cartesian(start,end,step):
    x = y = np.linspace(start,end,step)
    result = np.transpose([np.tile(x, len(y)), np.repeat(y, len(x))])
            
    return result

# %%
cartesian(1,10,10).shape
# Out:
# (101, 2)

# %%
## sigmoid 


def sigmoid(z):
    np.exp

def sigmoid(w,x,b=0,range=20):
    """
    takes w -vector [w_1,w_2,...,w_n,b] b intersection
    
    return real number 
    """
    z=np.array(w)
    result = z.dot(np.array(x))
    return result

# %%
w = [2,3,4]
x=[1,2,3]
#sigmoid(w,x,2)
[i+2 for i in w]
# Out:
# [4, 5, 6]

# %%
x = np.linspace(-100,100,120)

# %%
def sigmoid(x,a,b):
    z = [i*a +b for i in x]
    result = [1/(1+np.exp(-i)) for i in z ]
    return result

# %%
plt.plot(x,sigmoid(x,2,3))

# %%
def plot(num):
    """
    
    """
    
    size = np.sqrt(num)  
    a = cartesian(1,100,num_elemt)
  
    x = np.linspace(-10,10,30)
    if not size.is_integer():
        raise ValueError("num must has precise  root of integer type ")
    size = int(size)
    fig, axs = plt.subplots(size, size,figsize=(25,25))    
    for i in range(size):
        for j in range(size):
            axs[i, j].set_title('a = {} ,b = {}'.format(i,j)  )
            y=sigmoid(x,i,j)
            axs[i, j].plot(x,y)

# %%
plot(25)

# %% [markdown]
# ### The above graphic represents the sigmoid function with different a,b .The goal of logistic regression is to fit this curve thus to describe input data in most appropriate way

# %% [markdown]
# How we can fit and train model of logistic regression ,that is the main idea ,cross - entropu function
